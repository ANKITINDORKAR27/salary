# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('Salaries (1).csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df[['phd','salary']].describe()
# Out:
#              phd         salary
# count  78.000000      78.000000
# mean   19.705128  108023.782051
# std    12.498425   28293.661022
# min     1.000000   57800.000000
# 25%    10.250000   88612.500000
# 50%    18.500000  104671.000000
# 75%    27.750000  126774.750000
# max    56.000000  186960.000000

# %%
df[['phd','service','salary']].describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df[['service','phd','salary']].mean()
# Out:
# service        15.051282
# phd            19.705128
# salary     108023.782051
# dtype: float64

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
df[['service','phd']].mean()
# Out:
# service    15.051282
# phd        19.705128
# dtype: float64

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df['phd'].max()
# Out:
# 56

# %%
df[['phd','service','salary']].max()
# Out:
# phd            56
# service        51
# salary     186960
# dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.quantile(0.25)
# Out:
# phd           10.25
# service        5.25
# salary     88612.50
# Name: 0.25, dtype: float64

# %%
df.quantile(0.75)
# Out:
# phd            27.75
# service        20.75
# salary     126774.75
# Name: 0.75, dtype: float64

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.median()
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.mode()
# Out:
#    rank discipline  phd  service     sex   salary
# 0  Prof          B  4.0      3.0  Female  92000.0
# 1   NaN        NaN  NaN      NaN    Male      NaN

# %%
df['phd'].mode()
# Out:
# 0    4
# dtype: int64

# %%
df[['phd','salary']].mode()
# Out:
#    phd  salary
# 0    4   92000

# %%
df.count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df.shape
# Out:
# (78, 6)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[5,3]
# Out:
# 20

# %%
df.iloc[:,]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:7,1:2]
# Out:
#   discipline
# 0          B
# 1          A
# 2          A
# 3          A
# 4          B
# 5          A
# 6          A

# %%
df.iloc[[2,4,6,8,10],[2,3,4]]
# Out:
#     phd  service   sex
# 2    23       20  Male
# 4    20       18  Male
# 6    20       17  Male
# 8    29       19  Male
# 10   39       33  Male

# %%
df.iloc[0:100,0:100]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df['discipline']
# Out:
# 0     B
# 1     A
# 2     A
# 3     A
# 4     B
# 5     A
# 6     A
# 7     A
# 8     A
# 9     A
# 10    B
# 11    B
# 12    B
# 13    B
# 14    B
# 15    B
# 16    B
# 17    B
# 18    A
# 19    A
# 20    B
# 21    A
# 22    A
# 23    A
# 24    A
# 25    B
# 26    A
# 27    A
# 28    B
# 29    B
#      ..
# 48    B
# 49    B
# 50    B
# 51    B
# 52    A
# 53    A
# 54    A
# 55    A
# 56    A
# 57    A
# 58    B
# 59    B
# 60    B
# 61    B
# 62    B
# 63    A
# 64    A
# 65    A
# 66    A
# 67    A
# 68    A
# 69    A
# 70    A
# 71    B
# 72    B
# 73    B
# 74    B
# 75    B
# 76    A
# 77    A
# Name: discipline, Length: 78, dtype: object

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df.groupby(['rank','sex'])['salary'].value_counts()
# Out:
# rank       sex     salary
# AssocProf  Female  62884     1
#                    71065     1
#                    73300     1
#                    74830     1
#                    77500     1
#                    103613    1
#                    103750    1
#                    103994    1
#                    104542    1
#                    109650    1
#            Male    81285     1
#                    107008    1
#                    119800    1
# AsstProf   Female  72500     2
#                    63100     1
#                    73500     1
#                    74692     1
#                    77000     1
#                    77500     1
#                    78500     1
#                    80225     1
#                    92000     1
#                    97032     1
#            Male    92000     2
#                    73000     1
#                    75044     1
#                    85000     1
#                    88000     1
#                    91000     1
# ...

# %%
df.groupby(['rank','service','sex'])['salary'].describe()
# Out:
#                           count           mean           std       min  \
# rank      service sex
# AssocProf 6       Female    1.0  104542.000000           NaN  104542.0
#           7       Female    1.0  109650.000000           NaN  109650.0
#                   Male      1.0  107008.000000           NaN  107008.0
#           8       Female    2.0   76165.000000   1887.975106   74830.0
#                   Male      1.0  119800.000000           NaN  119800.0
#           9       Female    1.0   71065.000000           NaN   71065.0
#           10      Female    2.0  103872.000000    172.534055  103750.0
#           11      Female    1.0  103613.000000           NaN  103613.0
#           17      Male      1.0   81285.000000           NaN   81285.0
#           22      Female    1.0   62884.000000           NaN   62884.0
#           24      Female    1.0   73300.000000           NaN   73300.0
# AsstProf  0       Female    2.0   74750.000000   3181.980515   72500.0
# ...

# %%
df.groupby(['rank','service'])['salary'].describe()
# Out:
#                    count           mean           std       min        25%  \
# rank      service
# AssocProf 6          1.0  104542.000000           NaN  104542.0  104542.00
#           7          2.0  108329.000000   1868.176116  107008.0  107668.50
#           8          3.0   90710.000000  25228.026082   74830.0   76165.00
#           9          1.0   71065.000000           NaN   71065.0   71065.00
#           10         2.0  103872.000000    172.534055  103750.0  103811.00
#           11         1.0  103613.000000           NaN  103613.0  103613.00
#           17         1.0   81285.000000           NaN   81285.0   81285.00
#           22         1.0   62884.000000           NaN   62884.0   62884.00
#           24         1.0   73300.000000           NaN   73300.0   73300.00
# AsstProf  0          5.0   82900.000000   8003.124390   72500.0   77000.00
#           1          1.0   72500.000000           NaN   72500.0   72500.00
# ...

# %%
df.groupby(['rank','service','sex'])['salary'].max()
# Out:
# rank       service  sex
# AssocProf  6        Female    104542
#            7        Female    109650
#                     Male      107008
#            8        Female     77500
#                     Male      119800
#            9        Female     71065
#            10       Female    103994
#            11       Female    103613
#            17       Male       81285
#            22       Female     62884
#            24       Female     73300
# AsstProf   0        Female     77000
#                     Male       92000
#            1        Female     72500
#            2        Female     80225
#                     Male       91300
#            3        Female     92000
#                     Male       91000
#            4        Male       92000
#            5        Female     97032
#            6        Female     63100
# Prof       0        Female    105000
#            3        Male      150480
#            6        Male       93000
# ...

# %%
df[(df['rank']=='AssocProf') & (df['discipline']=='A')]
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 41  AssocProf          A   13        8  Female   74830
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 64  AssocProf          A   26       24  Female   73300

# %%
print(df['salary'].head())
print(df[['salary','phd','service']].head())
# Out:
# 0    186960
# 1     93000
# 2    110515
# 3    131205
# 4    104800
# Name: salary, dtype: int64
#    salary  phd  service
# 0  186960   56       49
# 1   93000   12        6
# 2  110515   23       20
# 3  131205   40       31
# 4  104800   20       18

# %%
df['phd'].count()
# Out:
# 78

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
print('The maximum salary of AsstProf is Rs.',df[df['rank']=='AsstProf']['salary'].max())
# Out:
# The maximum salary of AsstProf is Rs. 97032

# %%
print('The minimum years of service for Prof is ',df[df['rank']=='Prof']['service'].min())
# Out:
# The minimum years of service for Prof is  0
