# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
beml_df=pd.read_csv('BEML.csv')

# %%
glaxo_df=pd.read_csv('GLAXO.csv')

# %%
beml_df.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
glaxo_df.head()
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
beml_df = beml_df[['Date','Close']]

# %%
glaxo_df = glaxo_df[['Date','Close']]

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# 5     2010-01-11  1137.00
# 6     2010-01-12  1143.65
# 7     2010-01-13  1142.25
# 8     2010-01-14  1148.20
# 9     2010-01-15  1207.05
# 10    2010-01-18  1236.25
# 11    2010-01-19  1221.25
# 12    2010-01-20  1186.20
# 13    2010-01-21  1150.15
# 14    2010-01-22  1170.75
# 15    2010-01-25  1154.70
# 16    2010-01-27  1058.60
# 17    2010-01-28  1039.30
# 18    2010-01-29  1068.95
# 19    2010-02-01  1140.10
# 20    2010-02-02  1107.95
# 21    2010-02-03  1118.80
# 22    2010-02-04  1090.30
# 23    2010-02-05  1070.45
# 24    2010-02-06  1080.40
# 25    2010-02-08  1095.65
# 26    2010-02-09  1109.00
# 27    2010-02-10  1095.45
# 28    2010-02-11  1120.55
# 29    2010-02-15  1139.65
# ...          ...      ...
# 1709  2016-11-21   807.85
# 1710  2016-11-22   785.05
# 1711  2016-11-23   786.05
# ...

# %%
beml_df.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# 5     2010-01-11  1137.00
# 6     2010-01-12  1143.65
# 7     2010-01-13  1142.25
# 8     2010-01-14  1148.20
# 9     2010-01-15  1207.05
# 10    2010-01-18  1236.25
# 11    2010-01-19  1221.25
# 12    2010-01-20  1186.20
# 13    2010-01-21  1150.15
# 14    2010-01-22  1170.75
# 15    2010-01-25  1154.70
# 16    2010-01-27  1058.60
# 17    2010-01-28  1039.30
# 18    2010-01-29  1068.95
# 19    2010-02-01  1140.10
# 20    2010-02-02  1107.95
# 21    2010-02-03  1118.80
# 22    2010-02-04  1090.30
# 23    2010-02-05  1070.45
# 24    2010-02-06  1080.40
# 25    2010-02-08  1095.65
# 26    2010-02-09  1109.00
# 27    2010-02-10  1095.45
# 28    2010-02-11  1120.55
# 29    2010-02-15  1139.65
# ...          ...      ...
# 1709  2016-11-21   807.85
# 1710  2016-11-22   785.05
# 1711  2016-11-23   786.05
# ...

# %%
glaxo_df.head()
# Out:
#          Date    Close
# 0  2010-01-04  1625.65
# 1  2010-01-05  1616.80
# 2  2010-01-06  1638.50
# 3  2010-01-07  1648.70
# 4  2010-01-08  1639.80

# %%
beml_df = beml_df.set_index(pd.DatetimeIndex(beml_df['Date'])).drop('Date',axis = 1)

# %%
glaxo_df = glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date'])).drop('Date',axis = 1)

# %%
beml_df.head()
# Out:
#               Close
# Date
# 2010-01-04  1135.60
# 2010-01-05  1134.60
# 2010-01-06  1139.60
# 2010-01-07  1144.15
# 2010-01-08  1144.05

# %%
glaxo_df.head()
# Out:
#               Close
# Date
# 2010-01-04  1625.65
# 2010-01-05  1616.80
# 2010-01-06  1638.50
# 2010-01-07  1648.70
# 2010-01-08  1639.80

# %%
import matplotlib.pyplot as plt
import seaborn as sn
plt.plot(glaxo_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');
plt.title('GLAXO DATA');

# %%
plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');
plt.title('BEML DATA');

# %%
glaxo_df['gain'] = glaxo_df.Close.pct_change(periods = 1)
beml_df['gain'] = beml_df.Close.pct_change(periods = 1)

# %%
glaxo_df
# Out:
#               Close      gain
# Date
# 2010-01-04  1625.65       NaN
# 2010-01-05  1616.80 -0.005444
# 2010-01-06  1638.50  0.013422
# 2010-01-07  1648.70  0.006225
# 2010-01-08  1639.80 -0.005398
# 2010-01-11  1629.45 -0.006312
# 2010-01-12  1583.85 -0.027985
# 2010-01-13  1571.30 -0.007924
# 2010-01-14  1573.55  0.001432
# 2010-01-15  1570.40 -0.002002
# 2010-01-18  1562.50 -0.005031
# 2010-01-19  1559.95 -0.001632
# 2010-01-20  1563.45  0.002244
# 2010-01-21  1539.55 -0.015287
# 2010-01-22  1514.30 -0.016401
# 2010-01-25  1532.05  0.011722
# 2010-01-27  1523.40 -0.005646
# 2010-01-28  1526.00  0.001707
# 2010-01-29  1520.45 -0.003637
# 2010-02-01  1540.75  0.013351
# 2010-02-02  1540.15 -0.000389
# 2010-02-03  1564.80  0.016005
# 2010-02-04  1561.30 -0.002237
# 2010-02-05  1559.95 -0.000865
# 2010-02-06  1561.90  0.001250
# 2010-02-08  1529.10 -0.021000
# 2010-02-09  1530.40  0.000850
# 2010-02-10  1561.05  0.020027
# 2010-02-11  1578.85  0.011403
# 2010-02-15  1578.95  0.000063
# ...

# %%
beml_df
# Out:
#               Close      gain
# Date
# 2010-01-04  1135.60       NaN
# 2010-01-05  1134.60 -0.000881
# 2010-01-06  1139.60  0.004407
# 2010-01-07  1144.15  0.003993
# 2010-01-08  1144.05 -0.000087
# 2010-01-11  1137.00 -0.006162
# 2010-01-12  1143.65  0.005849
# 2010-01-13  1142.25 -0.001224
# 2010-01-14  1148.20  0.005209
# 2010-01-15  1207.05  0.051254
# 2010-01-18  1236.25  0.024191
# 2010-01-19  1221.25 -0.012133
# 2010-01-20  1186.20 -0.028700
# 2010-01-21  1150.15 -0.030391
# 2010-01-22  1170.75  0.017911
# 2010-01-25  1154.70 -0.013709
# 2010-01-27  1058.60 -0.083225
# 2010-01-28  1039.30 -0.018232
# 2010-01-29  1068.95  0.028529
# 2010-02-01  1140.10  0.066561
# 2010-02-02  1107.95 -0.028199
# 2010-02-03  1118.80  0.009793
# 2010-02-04  1090.30 -0.025474
# 2010-02-05  1070.45 -0.018206
# 2010-02-06  1080.40  0.009295
# 2010-02-08  1095.65  0.014115
# 2010-02-09  1109.00  0.012185
# 2010-02-10  1095.45 -0.012218
# 2010-02-11  1120.55  0.022913
# 2010-02-15  1139.65  0.017045
# ...

# %%
glaxo_df = glaxo_df.dropna()

# %%
beml_df = beml_df.dropna()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 8));
plt.plot( glaxo_df.gain);
plt.xlabel('Time');
plt.ylabel('gain');
plt.title('GLAXO');

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,8));
plt.plot( beml_df.gain);
plt.xlabel('Time');
plt.ylabel('gain');
plt.title('BEML');

# %%
import seaborn as sn

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.suptitle('Distribution',fontsize=15)

sn.distplot(glaxo_df.gain, label = 'Glaxo');

plt.xlabel('gain')
plt.ylabel('Density');
plt.legend();

plt.subplot(1,2,2)
sn.distplot(beml_df.gain, label = 'BEML');

plt.xlabel('gain')
plt.ylabel('Density');
plt.legend();

# %%
glaxo_df['loss'] = glaxo_df.Close.pct_change(periods = 2)
beml_df['loss'] = beml_df.Close.pct_change(periods = 2)

# %%
glaxo_df.head()
# Out:
#               Close      gain      loss
# Date
# 2010-01-05  1616.80 -0.005444       NaN
# 2010-01-06  1638.50  0.013422       NaN
# 2010-01-07  1648.70  0.006225  0.019730
# 2010-01-08  1639.80 -0.005398  0.000793
# 2010-01-11  1629.45 -0.006312 -0.011676

# %%
beml_df.head()
# Out:
#               Close      gain      loss
# Date
# 2010-01-05  1134.60 -0.000881       NaN
# 2010-01-06  1139.60  0.004407       NaN
# 2010-01-07  1144.15  0.003993  0.008417
# 2010-01-08  1144.05 -0.000087  0.003905
# 2010-01-11  1137.00 -0.006162 -0.006249

# %%
# Out:
#               Close      gain
# Date
# 2010-01-05  1616.80 -0.005444
# 2010-01-06  1638.50  0.013422
# 2010-01-07  1648.70  0.006225
# 2010-01-08  1639.80 -0.005398
# 2010-01-11  1629.45 -0.006312
# 2010-01-12  1583.85 -0.027985
# 2010-01-13  1571.30 -0.007924
# 2010-01-14  1573.55  0.001432
# 2010-01-15  1570.40 -0.002002
# 2010-01-18  1562.50 -0.005031
# 2010-01-19  1559.95 -0.001632
# 2010-01-20  1563.45  0.002244
# 2010-01-21  1539.55 -0.015287
# 2010-01-22  1514.30 -0.016401
# 2010-01-25  1532.05  0.011722
# 2010-01-27  1523.40 -0.005646
# 2010-01-28  1526.00  0.001707
# 2010-01-29  1520.45 -0.003637
# 2010-02-01  1540.75  0.013351
# 2010-02-02  1540.15 -0.000389
# 2010-02-03  1564.80  0.016005
# 2010-02-04  1561.30 -0.002237
# 2010-02-05  1559.95 -0.000865
# 2010-02-06  1561.90  0.001250
# 2010-02-08  1529.10 -0.021000
# 2010-02-09  1530.40  0.000850
# 2010-02-10  1561.05  0.020027
# 2010-02-11  1578.85  0.011403
# 2010-02-15  1578.95  0.000063
# 2010-02-16  1569.30 -0.006112
# ...

# %%
glaxo_df['loss'] = glaxo_df.Close.pct_change(periods = 2)

# %%
glaxo_df.head()
# Out:
#               Close      gain      loss
# Date
# 2010-01-05  1616.80 -0.005444       NaN
# 2010-01-06  1638.50  0.013422       NaN
# 2010-01-07  1648.70  0.006225  0.019730
# 2010-01-08  1639.80 -0.005398  0.000793
# 2010-01-11  1629.45 -0.006312 -0.011676

# %%
print('Mean:', round(glaxo_df.Close.mean(), 2))
print('Standard Deviation: ', round(glaxo_df.Close.std(), 2))
# Out:
# Mean: 2533.15
# Standard Deviation:  540.44

# %%
print('Mean:',round(beml_df.Close.mean(),2))
print('Standard Deviation:',round(beml_df.Close.std(),2))
# Out:
# Mean: 698.18
# Standard Deviation: 357.38

# %%
from scipy import stats

# %%
glaxo_df = glaxo_df.drop('loss',axis=1)

# %%
beml_df = beml_df.drop('loss',axis=1)

# %%
print('Mean:', round(glaxo_df.gain.mean(), 2))
print('Standard Deviation: ', round(glaxo_df.gain.std(), 2))
# Out:
# Mean: 0.0
# Standard Deviation:  0.01

# %%
print('Mean:',round(beml_df.gain.mean(),2))
# Out:
# Mean: 0.0

# %%
print('Standard Deviation:',round(beml_df.gain.std(),2))
# Out:
# Standard Deviation: 0.03

# %%
stats.norm.cdf( -0.02,0.0004, 0.0134)
# Out:
# 0.06395593743937553

# %%
stats.norm.cdf(0.02,0.0004,0.0134)
# Out:
# 0.9282234182680936

# %%
1-stats.norm.cdf( 0.02,0.0004, 0.0134)
# Out:
# 0.07177658173190637

# %%
stats.norm.cdf( -0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22155987503755292

# %%
1 - stats.norm.cdf(0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22769829484075343
